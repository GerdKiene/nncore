# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("simulator_output")

# %%
times = data[:,0]
voltages = data[:,1]
currents = data[:,2]

# %%
fig = plt.figure(figsize=[10, 4])

ax = fig.gca()
ax.plot(times[:], voltages[:])

# %%
fig = plt.figure(figsize=[10, 4])

ax = fig.gca()
ax.plot(times[1500:2000], currents[1500:2000])
